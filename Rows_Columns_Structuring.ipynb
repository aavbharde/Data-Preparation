# %%
import pandas as pd

# %%
file_read = pd.read_csv('C:/Users/aakan/Desktop/Stevens/Semester 2/Self_Study/Python/Data Cleaning/python-data-cleaning-master/Datasets/olympics.csv')

# %%
file_read.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  ? Summer  01 !  02 !  03 !  Total  ? Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  ? Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
file_read = pd.read_csv('C:/Users/aakan/Desktop/Stevens/Semester 2/Self_Study/Python/Data Cleaning/python-data-cleaning-master/Datasets/olympics.csv',header=1)

# %%
file_read.head()
# Out:
#                 Unnamed: 0  ? Summer  01 !  02 !  03 !  Total  ? Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %%
renaming_dict = {
'Unnamed: 0':'Country','? Summer':'Summer Session','01 !':'Gold_Summer','02 !':'Silver_Summer','03 !':'Bronze_Summer','Total':'Total_Summer','? Winter':'Winter Session','01 !.1':'Gold_Winter','02 !.1':'Silver_Winter','03 !.1':'Bronze_Winter','Total.1':'Total_Winter','? Games':'Summer+Winter','01 !.2':'Gold_Total','02 !.2':'Silver_Total','03 !.2':'Bronze_Total','Combined total':'Total_Summer+Total_Winter'}

# %%
file_read.rename(columns=renaming_dict)
# Out:
#                                           Country  Summer Session  \
# 0                               Afghanistan (AFG)              13
# 1                                   Algeria (ALG)              12
# 2                                 Argentina (ARG)              23
# 3                                   Armenia (ARM)               5
# 4                         Australasia (ANZ) [ANZ]               2
# 5                       Australia (AUS) [AUS] [Z]              25
# 6                                   Austria (AUT)              26
# 7                                Azerbaijan (AZE)               5
# 8                                   Bahamas (BAH)              15
# 9                                   Bahrain (BRN)               8
# 10                           Barbados (BAR) [BAR]              11
# 11                                  Belarus (BLR)               5
# 12                                  Belgium (BEL)              25
# ...
